# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n-cls.pt") 

ruta_imagen=r'C:\Users\34611\Desktop\ecapture\dataset\damaged_signs_dataset_12gb\dataset\img_1040.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
# Use the model to detect object
results = model.train(data='C:\\Users\\34611\\Desktop\\ecapture\\clasificacion_12_gb_estado', epochs=10, imgsz=64)
# Out:
# New https://pypi.org/project/ultralytics/8.1.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.10 🚀 Python-3.9.2 torch-2.2.0+cpu CPU (Intel Core(TM) i7-1065G7 1.30GHz)
# ...

# %%
model.save()
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.9.2 torch-2.2.0+cpu CPU (Intel Core(TM) i7-1065G7 1.30GHz)
#
# PyTorch: starting from 'runs\classify\train8\weights\best.pt' with input shape (1, 3, 64, 64) BCHW and output shape(s) (1, 2) (2.8 MB)
#
# TorchScript: starting export with torch 2.2.0+cpu...
# TorchScript: export success ✅ 1.6s, saved as 'runs\classify\train8\weights\best.torchscript' (5.6 MB)
#
# Export complete (3.2s)
# Results saved to C:\Users\34611\ecapture\runs\classify\train8\weights
# Predict:         yolo predict task=classify model=runs\classify\train8\weights\best.torchscript imgsz=64
# Validate:        yolo val task=classify model=runs\classify\train8\weights\best.torchscript imgsz=64 data=C:\Users\34611\Desktop\ecapture\clasificacion_12_gb_estado
# Visualize:       https://netron.app
# 'runs\\classify\\train8\\weights\\best.torchscript'

# %%
from PIL import Image
ruta_imagen=r'C:\Users\34611\Desktop\damaged_traffic_sign.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[168] must be multiple of max stride 32, updating to [192]
# 0: 64x64 mal estado 0.92, buen estado 0.08, 13.8ms
# Speed: 26.8ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
ruta_imagen=r'C:\Users\34611\Desktop\images.png'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[225] must be multiple of max stride 32, updating to [256]
# 0: 64x64 buen estado 0.89, mal estado 0.11, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
ruta_imagen=r'C:\Users\34611\Desktop\traffic_sign_2.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[182] must be multiple of max stride 32, updating to [192]
# 0: 64x64 mal estado 0.71, buen estado 0.29, 14.7ms
# Speed: 4.7ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
ruta_imagen=r'C:\Users\34611\Desktop\imagen_dañada.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[1132] must be multiple of max stride 32, updating to [1152]
# 0: 64x64 mal estado 0.69, buen estado 0.31, 29.9ms
# Speed: 4.3ms preprocess, 29.9ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
ruta_imagen=r'C:\Users\34611\Desktop\imagen_dañada2.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[180] must be multiple of max stride 32, updating to [192]
# 0: 64x64 mal estado 0.63, buen estado 0.37, 6.4ms
# Speed: 4.1ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
ruta_imagen=r'C:\Users\34611\Desktop\stop.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[247] must be multiple of max stride 32, updating to [256]
# 0: 64x64 mal estado 0.58, buen estado 0.42, 2.8ms
# Speed: 7.1ms preprocess, 2.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
ruta_imagen=r'C:\Users\34611\Desktop\buen_estado_3.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
result_predict = model.predict(source = image, imgsz=(h))
# Out:
# 0: 64x64 mal estado 0.70, buen estado 0.30, 7.8ms
# Speed: 25.3ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
def get_bounding_box(image_w,image_h,x_center, y_center, w, h):
        #coordinates of the bounding box
        x_center_pixel= x_center * image_w
        y_center_pixel= y_center * image_h
        half_w=(w*image_w)/2
        half_h=(h*image_h)/2


        xmin=int(x_center_pixel-half_w)
        xmax=int(x_center_pixel+half_w)
        ymin=int(y_center_pixel-half_h)
        ymax=int(y_center_pixel+half_h)

        return(xmin,xmax,ymin,ymax)
    
def crop(imagen,label):
    import cv2
    image = cv2.imread(imagen)
    image_h,image_w,_=image.shape
    v=get_bounding_box(image_w,image_h,float(label[0]), float(label[1]), float(label[2]), float(label[3]))
    y,h,x,w=v
    crop_image = image[x:w, y:h]
    cv2.imshow('Cropped', crop_image)
    cv2.waitKey(0)
    return(crop_image)

def guardar_imagen(imagen, directorio_destino, nombre_archivo):

    # Guardar la imagen en el directorio especificado
    if not os.path.exists(directorio_destino):
        os.makedirs(directorio_destino)
    
    ruta_destino = os.path.join(directorio_destino, nombre_archivo)
    plt.imsave(ruta_destino, imagen)  # Guardar la imagen usando plt.imsave()

# %%
from ultralytics import YOLO 
model2 = YOLO("signal_detector_model.pt") 
import os
from PIL import Image
import matplotlib.pyplot as plt


#Ruta de la carpeta que contiene las clases
carpeta=r'C:\Users\34611\Desktop\prueba_yolo'
archivos=os.listdir(carpeta)

ruta_imagen=r'C:\Users\34611\Desktop\folded.jpg'
image = cv2.imread(ruta_imagen)
h, w, c = image.shape
# Use the model to detect object
result_predict = model2.predict(source = image, imgsz=(h))
        
# show results
plot = result_predict[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
for i in range (len(result_predict[0].boxes)):
    label=result_predict[0].boxes[i].xywhn.tolist()
    label=label[0]
    guardar_imagen(crop(ruta_imagen,label),'C:\\Users\\34611\\Desktop\\prueba_yolo','recorte_ejemplo'+str(i)+'.jpg')
# Out:
# WARNING ⚠️ imgsz=[268] must be multiple of max stride 32, updating to [288]
# 0: 160x288 3 379s, 334.7ms
# Speed: 10.7ms preprocess, 334.7ms inference, 15.6ms postprocess per image at shape (1, 3, 160, 288)
# <PIL.Image.Image image mode=RGB size=483x268>

# %%
#inversión del rojo y el azul
import os
from PIL import Image
import matplotlib.pyplot as plt

carpeta='C:\\Users\\34611\\Desktop\\prueba_yolo'
archivos=os.listdir(carpeta)
# Iterar sobre cada archivo en la carpeta
for nombre_archivo in archivos:
    # Verificar si el archivo es una imagen (puedes ajustar las extensiones según tus necesidades)
    if nombre_archivo.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
        # Construir la ruta completa del archivo
        ruta_archivo = os.path.join(carpeta, nombre_archivo)

        # Cargar la imagen con Pillow
        datos_imagen = plt.imread(ruta_archivo)

        # Intercambiar canales rojo y azul
        datos_imagen_intercambiados = datos_imagen[:, :, [2, 1, 0]]  # Intercambia el canal rojo con el azul

        # Guardar la imagen con canales intercambiados
        ruta_guardada = os.path.join(carpeta, nombre_archivo)
        plt.imsave(ruta_guardada,datos_imagen_intercambiados)

print("Proceso completado para todas las imágenes en la carpeta.")
# Out:
# Proceso completado para todas las imágenes en la carpeta.

# %%
carpeta=r'C:\Users\34611\Desktop\prueba_yolo'
archivos=os.listdir(carpeta)
for archivo in archivos:
    ruta_imagen=os.path.join(carpeta,archivo)
    image = cv2.imread(ruta_imagen)
    h, w, c = image.shape
    result_predict = model.predict(source = image, imgsz=(h))
# Out:
# WARNING ⚠️ imgsz=[71] must be multiple of max stride 32, updating to [96]
# 0: 64x64 buen estado 0.71, mal estado 0.29, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# WARNING ⚠️ imgsz=[16] must be multiple of max stride 32, updating to [32]
# 0: 64x64 buen estado 0.89, mal estado 0.11, 11.7ms
# Speed: 8.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)
#
# WARNING ⚠️ imgsz=[44] must be multiple of max stride 32, updating to [64]
# 0: 64x64 mal estado 0.87, buen estado 0.13, 17.1ms
# Speed: 5.5ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
#MÉTRICAS
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Ejemplo de etiquetas reales y predicciones
y_true = [1, 0, 1, 1, 0, 1, 0, 0, 1, 0]
y_pred = [1, 0, 1, 1, 0, 0, 1, 0, 1, 0]

# Exactitud (Accuracy)
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Precisión (Precision)
precision = precision_score(y_true, y_pred)
print(f'Precision: {precision:.2f}')

# Recall (Sensibilidad)
recall = recall_score(y_true, y_pred)
print(f'Recall: {recall:.2f}')

# F1-Score
f1 = f1_score(y_true, y_pred)
print(f'F1-Score: {f1:.2f}')

# Matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred)
print('Matriz de Confusión:')
print(conf_matrix)

# Curva ROC y Área bajo la curva (AUC-ROC)
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
auc_roc = roc_auc_score(y_true, y_pred)

# Visualización de la Curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_roc:.2f}')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend()
plt.show()
